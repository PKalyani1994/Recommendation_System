# %% [markdown]
# <a href="https://colab.research.google.com/github/PKalyani1994/Recommendation_System/blob/copy/Copy_Mid_ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Padala Kalyani

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
books_df = pd.read_csv('/content/Books.csv',low_memory=False)
ratings = pd.read_csv('/content/Ratings.csv')
users = pd.read_csv('/content/Users.csv')

# %%
print(books_df.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books_df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
books_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
users.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### popularity based

# %%
books = books_df[['ISBN', 'Book-Title', 'Book-Author']]

# %%
df = ratings.merge(books,on='ISBN')

# %%
df
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
rating_count_df = df.groupby('Book-Title')['Book-Rating'].count().reset_index().rename(columns = {'Book-Rating':'Rating-count'})
rating_count_df
# Out:
#                                                Book-Title  Rating-count
# 0        A Light in the Storm: The Civil War Diary of ...             4
# 1                                   Always Have Popsicles             1
# 2                    Apple Magic (The Collector's series)             1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...             1
# 4        Beyond IBM: Leadership Marketing and Finance ...             1
# ...                                                   ...           ...
# 241066                                      Ã?Â?lpiraten.             2
# 241067                     Ã?Â?rger mit Produkt X. Roman.             4
# 241068                                Ã?Â?sterlich leben.             1
# 241069                              Ã?Â?stlich der Berge.             3
# 241070                                  Ã?Â?thique en toc             2
#
# [241071 rows x 2 columns]

# %%
rating_mean_df = df.groupby('Book-Title')['Book-Rating'].mean().reset_index().rename(columns = {'Book-Rating':'Rating-mean'})
rating_mean_df
# Out:
#                                                Book-Title  Rating-mean
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
merged_df = rating_count_df.merge(rating_mean_df,on='Book-Title')

# %%
popular_df = merged_df[merged_df['Rating-count']>=250].sort_values(by='Rating-mean',ascending=False).head(50)
popular_df.shape
# Out:
# (50, 3)

# %%
popular_df = popular_df.merge(books_df, on='Book-Title').drop_duplicates('Book-Title')
popular_df.shape
# Out:
# (50, 10)

# %%
popular_df = popular_df[['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher','Image-URL-S','Rating-count','Rating-mean']]
popular_df
# Out:
#            ISBN                                         Book-Title  \
# 0    0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 3    0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 5    0590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 9    043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 13   0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 16   0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 17   0345339703  The Fellowship of the Ring (The Lord of the Ri...
# 26   059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 28   0345339711     The Two Towers (The Lord of the Rings, Part 2)
# 39   0446310786                              To Kill a Mockingbird
# 47   0385504209                                  The Da Vinci Code
# 53   0786868716                 The Five People You Meet in Heaven
# 55   0316769487                             The Catcher in the Rye
# ...

# %%
popular_df.shape
# Out:
# (50, 8)

# %% [markdown]
# ### populaity filtering using weighted average

# %%
merged_df.shape
# Out:
# (241071, 3)

# %%
df
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
df_1 = df.merge(users,on='User-ID')
df_1
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
explicit_ratings = df_1[df_1['Book-Rating'] != 0]
implicit_ratings = df_1[df_1['Book-Rating'] == 0]

# %%
explicit_ratings.shape, implicit_ratings.shape
# Out:
# ((383842, 7), (647294, 7))

# %%
explicit_ratings['ISBN'].nunique()
# Out:
# 149836

# %%
explicit_ratings = explicit_ratings.copy()

explicit_ratings['Rating-count'] = explicit_ratings.groupby('ISBN')['Book-Rating'].transform('count')
explicit_ratings['Rating-mean']  = explicit_ratings.groupby('ISBN')['Book-Rating'].transform('mean')
books_copy = books_df[['ISBN','Publisher','Year-Of-Publication']]
final_popular_df = explicit_ratings.merge(books_copy,on='ISBN')

# %%
final_popular_df
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276726  0155061224            5
# 1        276729  052165615X            3
# 2        276729  0521795028            6
# 3        276744  038550120X            7
# 4        276747  0060517794            9
# ...         ...         ...          ...
# 383837   276704  0743211383            7
# 383838   276704  0806917695            5
# 383839   276704  1563526298            9
# 383840   276709  0515107662           10
# 383841   276721  0590442449           10
#
#                                                Book-Title        Book-Author  \
# 0                                        Rites of Passage         Judith Rae
# 1                                          Help!: Level 1      Philip Prowse
# 2       The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# 3                                         A Painted House       JOHN GRISHAM
# 4                                Little Altars Everywhere      Rebecca Wells
# ...

# %%
c = final_popular_df['Rating-mean'].mean()
m = final_popular_df['Rating-count'].quantile(0.90)
popular_books_df = final_popular_df[final_popular_df['Rating-count'] >= m]
print(f'C={c} , m={m}')
popular_books_df.shape
# Out:
# C=7.626700569505161 , m=64.0
# (38570, 11)

# %% [markdown]
# **popularity index**:
#
# WR = [(v * R)/(v + m)] + [(m * c)/(v + m)]
#
# where,
#
# v is the number of votes for the books;
#
# m is the minimum votes required to be listed in the chart;
#
# R is the average rating of the book; and
#
# C is the mean vote across the whole report.

# %%
def weighted_average(my_df,m=m,c=c):
  v = my_df['Rating-count']
  r = my_df['Rating-mean']
  return ((v * r)/(v + m)) + ((m * c)/(v + m))

# %%
final_popular_df['Popularity_Index'] = final_popular_df.apply(weighted_average, axis=1)
final_popular_df = final_popular_df.sort_values('Popularity_Index', ascending=False)
final_popular_df = final_popular_df.drop_duplicates('ISBN')

# %%
final_popular_df = final_popular_df.reset_index(drop=True)
final_popular_df.head(20)
# Out:
#     User-ID        ISBN  Book-Rating  \
# 0    153971  0439139597            9
# 1     10697  059035342X           10
# 2    126693  043935806X           10
# 3    178953  0446310786            9
# 4    267830  0439136369            8
# 5    225078  0345339738            9
# 6    169192  0439136350           10
# 7    139458  0590353403           10
# 8     57398  0439064872           10
# 9    143964  0439064864            8
# 10   276463  0345339711           10
# 11   272786  0439139600            9
# 12   163605  0345339703           10
# 13   230496  0345339681           10
# 14    20834  0812550706            5
# 15    40541  0385484518            7
# 16    61147  0064400557           10
# 17   231374  0441172717           10
# 18   111888  0345361792            9
# 19    40330  0345342968            7
#
#                                            Book-Title       Book-Author  \
# 0        Harry Potter and the Goblet of Fire (Book 4)     J. K. Rowling
# ...
